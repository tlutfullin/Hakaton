# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv('train_dataset_train.csv')
df_test = pd.read_csv('test_dataset_test.csv')

# %%
df_train
# Out:
#           ID  Код_группы  Год_Поступления  Пол Основания   Изучаемый_Язык  \
# 0      72716       16019             2015  Жен        ОО  Английский язык
# 1      63306       14895             2010  Муж        ЦН              NaN
# 2      82469       20103             2017  Жен        ДН  Английский язык
# 3      81661       19838             2017  Жен        БН  Английский язык
# 4      81509       19803             2017  Жен        БН  Английский язык
# ...      ...         ...              ...  ...       ...              ...
# 13579  74283       17593             2016  Муж        ОО  Английский язык
# 13580  71516       19433             2015  Жен        ОО    Немецкий язык
# 13581  76970       18723             2016  Муж        СН  Английский язык
# 13582  48548       14663             2012  Жен        ОО              NaN
# 13583  80923       19869             2017  Жен        БН  Английский язык
#
#                  Дата_Рождения  \
# 0      1998-02-08 00:00:00.000
# ...

# %%
df_test
# Out:
#          ID  Код_группы  Год_Поступления  Пол Основания   Изучаемый_Язык  \
# 0     64996       20608             2014  Жен        ДН  Английский язык
# 1     71837       20613             2015  Жен        ДН    Немецкий язык
# 2     86587       21210             2018  Жен        ОО  Английский язык
# 3     73673       22254             2015  Жен        ОО  Английский язык
# 4     54709       15040             2012  Жен        ОО              NaN
# ...     ...         ...              ...  ...       ...              ...
# 6686  74342       20680             2016  Муж        БН  Английский язык
# 6687  54876       16921             2013  Жен        ОО              NaN
# 6688  66879       19400             2014  Жен        СН  Английский язык
# 6689  64982       18152             2014  Муж        ОО    Немецкий язык
# 6690  69975       17312             2015  Муж        ОО  Английский язык
#
#                 Дата_Рождения  \
# 0     1995-11-03 00:00:00.000
# ...

# %% [markdown]
# ● -1 – ушел в академический отпуск
# ● 4 – закончил обучение
# ● 3 – отчислен
# ● 5 – призван в армию

# %%
df_train.dtypes
# Out:
# ID                    int64
# Код_группы            int64
# Год_Поступления       int64
# Пол                  object
# Основания            object
# Изучаемый_Язык       object
# Дата_Рождения        object
# Уч_Заведение         object
# Где_Находится_УЗ     object
# Год_Окончания_УЗ    float64
# Пособие             float64
# Страна_ПП            object
# Регион_ПП            object
# Город_ПП             object
# Общежитие           float64
# Наличие_Матери        int64
# Наличие_Отца        float64
# Страна_Родители      object
# Опекунство          float64
# Село                float64
# Иностранец          float64
# КодФакультета       float64
# СрБаллАттестата     float64
# Статус                int64
# dtype: object

# %%
## Изменение название столбцов
## df.rename(columns={'b': 'k', 'c': 'm'}, inplace=True)

# %%
## показывает описательную характеристику, параметр all - описывает как числовые, так и категориальныых 
df_train.describe(include='all')
# Out:
#                    ID    Код_группы  Год_Поступления    Пол Основания  \
# count    13584.000000  13584.000000     13584.000000  13577     13584
# unique            NaN           NaN              NaN      3         5
# top               NaN           NaN              NaN    Жен        ОО
# freq              NaN           NaN              NaN   8133      5084
# mean     70096.056905  18302.499926      2014.992123    NaN       NaN
# std      12705.894531   2540.417956         2.595339    NaN       NaN
# min      44632.000000  11550.000000      2001.000000    NaN       NaN
# 25%      63496.750000  16901.000000      2013.000000    NaN       NaN
# 50%      71401.500000  18534.500000      2015.000000    NaN       NaN
# 75%      78404.250000  20599.000000      2016.000000    NaN       NaN
# max     264403.000000  22824.000000      2212.000000    NaN       NaN
#
#          Изучаемый_Язык            Дата_Рождения  \
# count             12758                    13584
# ...

# %%
df_train.dtypes
# Out:
# ID                    int64
# Код_группы            int64
# Год_Поступления       int64
# Пол                  object
# Основания            object
# Изучаемый_Язык       object
# Дата_Рождения        object
# Уч_Заведение         object
# Где_Находится_УЗ     object
# Год_Окончания_УЗ    float64
# Пособие             float64
# Страна_ПП            object
# Регион_ПП            object
# Город_ПП             object
# Общежитие           float64
# Наличие_Матери        int64
# Наличие_Отца        float64
# Страна_Родители      object
# Опекунство          float64
# Село                float64
# Иностранец          float64
# КодФакультета       float64
# СрБаллАттестата     float64
# Статус                int64
# dtype: object

# %%
df_train['Год_Поступления'].value_counts()
# Out:
# 2015    2353
# 2014    2290
# 2016    2271
# 2013    2070
# 2017    1460
# 2012    1394
# 2018    1147
# 2019     466
# 2020      48
# 2011      46
# 2010      19
# 2009       8
# 2007       5
# 2008       2
# 2212       1
# 2001       1
# 2004       1
# 2005       1
# 2003       1
# Name: Год_Поступления, dtype: int64

# %%
df_train['Общежитие'].value_counts()
# Out:
# 0.0    10530
# 1.0     2968
# Name: Общежитие, dtype: int64

# %%
## *Пособия* в тренировочной выборке 

df_train['Пособие'].value_counts()
# Out:
# 0.0    12576
# Name: Пособие, dtype: int64

# %%
## *Пособие* в тестовой выборке
df_test['Пособие'].value_counts()
# Out:
# 0.0    6207
# Name: Пособие, dtype: int64

# %%
## Можно удалить столбец *Пособие*
df_train = df_train.drop('Пособие',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13792/1344959679.py in <module>
#       1 ## Можно удалить столбец *Пособие*
# ----> 2 df_train = df_train.drop('Пособие',axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df_train['КодФакультета'].value_counts()
# Out:
# 26.0    2776
# 25.0    2171
# 41.0    1485
# 51.0    1109
# 34.0     960
# 24.0     692
# 27.0     679
# 28.0     662
# 31.0     622
# 35.0     547
# 40.0     471
# 36.0     447
# 30.0     435
# 48.0     234
# 45.0      91
# 47.0      84
# 49.0      76
# 46.0      26
# 53.0      15
# 37.0       2
# Name: КодФакультета, dtype: int64

# %%
df_train['СрБаллАттестата'].value_counts()
# Out:
# 70.0000      332
# 60.0000      324
# 80.0000      309
# 65.0000      302
# 55.0000      291
#             ...
# 4.2631         1
# 4.9440         1
# 4.2170         1
# 3.7060         1
# 3647.0000      1
# Name: СрБаллАттестата, Length: 462, dtype: int64

# %%
##● -1 – ушел в академический отпуск
##● 4 – закончил обучение
##● 3 – отчислен
##● 5 – призван в армию


##-продолжит ли студент обучение
##- отчислится
##- возьмет академический отпуск



df_train['Статус'].value_counts()
# Out:
#  4    8249
#  3    4721
# -1     614
# Name: Статус, dtype: int64

# %%
## Отбираю строки, которые удовлевторяют условию: студент поступил в 2020 году
df_train.loc[df_train['Год_Поступления'] ==2020].reset_index(drop=True)
# Out:
#         ID  Код_группы  Год_Поступления  Пол Основания  \
# 0   108117       22497             2020  Муж        ОО
# 1   118348       22633             2020  Жен        СН
# 2   101553       22442             2020  Муж        ОО
# 3   118347       22572             2020  Муж        ОО
# 4   107535       22531             2020  Жен        ОО
# 5   105860       22686             2020  Жен        СН
# 6   103425       22409             2020  Жен        ЦН
# 7   107273       22675             2020  Муж        СН
# 8   106618       22753             2020  Муж        СН
# 9   118338       22575             2020  Жен        СН
# 10  103545       22750             2020  Жен        СН
# 11  105898       22696             2020  Жен        СН
# 12  104973       22525             2020  Жен        ОО
# 13  108202       22701             2020  Муж        СН
# 14  105249       22696             2020  Жен        СН
# 15  118312       22577             2020  Жен        СН
# ...

# %%
## Удалить стоблец, который использовался до этого 
df_train.drop('Год_Поступления',axis=1)
# Out:
#           ID  Код_группы  Пол Основания   Изучаемый_Язык  \
# 0      72716       16019  Жен        ОО  Английский язык
# 1      63306       14895  Муж        ЦН              NaN
# 2      82469       20103  Жен        ДН  Английский язык
# 3      81661       19838  Жен        БН  Английский язык
# 4      81509       19803  Жен        БН  Английский язык
# ...      ...         ...  ...       ...              ...
# 13579  74283       17593  Муж        ОО  Английский язык
# 13580  71516       19433  Жен        ОО    Немецкий язык
# 13581  76970       18723  Муж        СН  Английский язык
# 13582  48548       14663  Жен        ОО              NaN
# 13583  80923       19869  Жен        БН  Английский язык
#
#                  Дата_Рождения  \
# 0      1998-02-08 00:00:00.000
# 1      1992-04-18 00:00:00.000
# 2      1999-03-21 00:00:00.000
# 3      1994-12-08 00:00:00.000
# 4      1995-06-28 00:00:00.000
# ...                        ...
# 13579  1998-09-17 00:00:00.000
# ...

# %%
corr=df_train.corr()
corr
# Out:
#                         ID  Код_группы  Год_Поступления  Год_Окончания_УЗ  \
# ID                1.000000    0.764826         0.695542          0.403148
# Код_группы        0.764826    1.000000         0.579809          0.393579
# Год_Поступления   0.695542    0.579809         1.000000          0.444285
# Год_Окончания_УЗ  0.403148    0.393579         0.444285          1.000000
# Пособие                NaN         NaN              NaN               NaN
# Общежитие         0.059165    0.087827         0.068872          0.158369
# Наличие_Матери    0.227340    0.246644         0.193887          0.188252
# Наличие_Отца      0.233302    0.249594         0.197208          0.189574
# Опекунство        0.011990    0.006243         0.014914          0.010188
# Село             -0.015480   -0.031974        -0.016431          0.021259
# Иностранец        0.112968    0.084208         0.086738          0.056972
# КодФакультета     0.063387   -0.002302         0.036665         -0.017714
# ...

# %%
import matplotlib.pyplot as plt

# %%
## строит тепловую карту матрицы корреляции 

import seaborn as sn
corrMatrix = df_train.corr()
f, ax = plt.subplots(figsize=(12, 9))
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %%
## Строит карту рассеянности 
sn.pairplot(df_train, kind='scatter')

# %%
_ = df_train[df_train.columns].hist(figsize=(20,12))

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13584 entries, 0 to 13583
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                13584 non-null  int64
#  1   Код_группы        13584 non-null  int64
#  2   Год_Поступления   13584 non-null  int64
#  3   Пол               13577 non-null  object
#  4   Основания         13584 non-null  object
#  5   Изучаемый_Язык    12758 non-null  object
#  6   Дата_Рождения     13584 non-null  object
#  7   Уч_Заведение      12351 non-null  object
#  8   Где_Находится_УЗ  12203 non-null  object
#  9   Год_Окончания_УЗ  12284 non-null  float64
#  10  Страна_ПП         13237 non-null  object
#  11  Регион_ПП         12966 non-null  object
#  12  Город_ПП          13141 non-null  object
#  13  Общежитие         13498 non-null  float64
#  14  Наличие_Матери    13584 non-null  int64
#  15  Наличие_Отца      13584 non-null  float64
# ...

# %% [markdown]
# У нас есть пропуски данных
# - Пол
# - Изучаемый_Язык
# - Уч_Заведение
# - Где_Находится_УЗ
# - Год_Окончания_УЗ
# - Страна_ПП
# - Регион_ПП
# - Город_ПП
# - Страна_Родители
# - Село
# - Иностранец
# -

# %%
## Посмотрим уникальные значения соответствуюих 
df_train['Изучаемый_Язык'].unique()
# Out:
# array(['Английский язык', nan, 'Немецкий язык', 'Французский язык',
#        'Русский язык', 'Иностранный язык (Английский)',
#        'Иностранный язык (Немецкий)', 'Англиийский'], dtype=object)

# %%
df_train['Уч_Заведение'].unique()
# Out:
# array(['МБОУ "СОШ №59"', nan, 'МБОУ Алтайская СОШ №5', ...,
#        'Ленинградский государственный университет им. А.С. Пушкина',
#        'Автономная некоммерческая организация ВПО "Алтайская академия экономики и права (институт)',
#        'МКОУ "Георгиевская СОШ"'], dtype=object)

# %%
df_train['Где_Находится_УЗ'].unique()
# Out:
# array(['Алтайский край, Барнаул г', nan,
#        'Алтайский край, Алтайский р-н, Алтайское с', ...,
#        'Алтайский край Крутихинский р-он с. Боровое',
#        'Республика Казахстан В-Казахстанская область Усть-Каменогорск',
#        'Алтайский край, Ребрихинский р-н, Георгиевка с'], dtype=object)

# %%
df_train['Село'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
df_train['Страна_Родители'].unique()
# Out:
# array(['Россия', nan, 'Кыргызстан', 'Казахстан', 'Китай', 'Таджикистан',
#        'Киргизия', 'Туркменистан', 'Германия', 'Кыргызская Республика',
#        'Армения', 'Республика Молдова', 'Республика Таджикистан',
#        'Нигерия', 'Узбекистан', 'Республика Казахстан', 'Монголия',
#        'казахстан', 'Украина', 'КНР'], dtype=object)

# %%
df_train['Страна_ПП'].unique()
# Out:
# array(['Россия', nan, 'Казахстан', 'Кыргызстан', 'Китай', 'Таджикистан',
#        'Казахстан Респ', 'Киргизия', 'Казахстан респ', 'РОССИЯ',
#        'Армения', 'Туркменистан', 'Нигерия', 'Таджикистан Респ',
#        'Росссия', 'Узбекистан', 'Кыргызия', 'Франция',
#        'Кыргызская Республика', 'Монголия', 'Казахстан ВКО',
#        'Республика Казахстан', 'Республика Таджикистан', 'Украина'],
#       dtype=object)

# %%
## Заменим Иностранный язык (Немецкий) --> Немецкий и тд., поскольку это одно и тоже
## Синтаксис для замены нескольких значений в столбце DataFrame:
## DataFrame.replace({'column_name' : { old_value_1 : new_value_1, old_value_2 : new_value_2}})
        
df_train = df_train.replace({'Изучаемый_Язык' : { 'Иностранный язык (Английский)': 'Английский язык', 
                                                  'Иностранный язык (Немецкий)': 'Немецкий язык' ,
                                                   'Англиийский' : 'Английский язык'} 
                 
                 })

# %%
df_train = df_train.replace( {'Страна_ПП' : {'Кыргызская Республика': 'Кыргызстан',
                                                  'Казахстан Респ': 'Казахстан',
                                                  'Казахстан респ':'Казахстан',
                                                  'РОССИЯ': 'Россия',
                                                  'Таджикистан Респ': 'Таджикистан',
                                                  'Росссия':'Россия',
                                                  'Кыргызия': 'Кыргызстан',
                                                  'Казахстан ВКО': 'Казахстан',
                                                  'Республика Казахстан': 'Казахстан',
                                                  'Республика Таджикистан': 'Таджикистан'}
                             })

# %%
df_train = df_train.replace({'Страна_Родители': {'Киргизия': 'Кыргызстан', 
                                                 'Кыргызская Республика': 'Кыргызстан',
                                                'Республика Молдова': 'Молдавия',
                                                'Республика Таджикистан' : 'Таджикистан',
                                                'Республика Казахстан' : 'Казахстан',
                                                'казахстан' : 'Казахстан',
                                                'КНР': 'Китай'}
                            })

# %%
Россия', nan, 'Кыргызстан', 'Казахстан', 'Китай', 'Таджикистан',
       'Киргизия', 'Туркменистан', 'Германия', 'Кыргызская Республика',
       'Армения', 'Республика Молдова', 'Республика Таджикистан',
       'Нигерия', 'Узбекистан', 'Республика Казахстан', 'Монголия',
       'казахстан', 'Украина', 'КНР'], dtype=object)

# %%
df_train['Изучаемый_Язык'].unique()
# Out:
# array(['Английский язык', nan, 'Немецкий язык', 'Французский язык',
#        'Русский язык'], dtype=object)

# %%
df_train['Страна_Родители'].unique()
# Out:
# array(['Россия', nan, 'Кыргызстан', 'Казахстан', 'Китай', 'Таджикистан',
#        'Туркменистан', 'Германия', 'Армения', 'Молдавия', 'Нигерия',
#        'Узбекистан', 'Монголия', 'Украина'], dtype=object)

# %%
df_train['Страна_ПП'].unique()
# Out:
# array(['Россия', nan, 'Казахстан', 'Кыргызстан', 'Китай', 'Таджикистан',
#        'Киргизия', 'Армения', 'Туркменистан', 'Нигерия', 'Узбекистан',
#        'Франция', 'Монголия', 'Украина'], dtype=object)
